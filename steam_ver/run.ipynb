# %% [markdown]
# # Testting game

# %%
from control_laptop import UmaGame, resize_game
# Out:
# Initialize logger for JSONLoader

# %%
resize_game()
# Out:
# 2025-12-09 23:17:54,186 - JSONLoader - INFO - Resized window 'Umamusume'

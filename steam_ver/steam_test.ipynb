# %% [markdown]
# # Run steam version
#
# - After you see training UI that have "Rest", "Training", "Skill",... run the code below, the screen size will automatic will change to 1440x

# %%
from control_laptop import UmaGame
import pygetwindow as gw
from horse_info import *

game = UmaGame(test=1, deck_name="Mayano Top Gun Wedding", character=Mayano_Top_Gun_Wedding)

# %% [markdown]
# ## Test function

# %%
game.turn=22
game.change_strategy()

# %%
game.turn=22
game.find_race()
# Out:
# Box(left=np.int64(1389), top=np.int64(714), width=104, height=55)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# c:\ProgramData\anaconda3\envs\AutoGame\Lib\site-packages\IPython\core\interactiveshell.py:3707: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
game.character.race_table[24]
# Out:
# 'Hopeful S'

# %%
# support_cards = ["Manhattan Cafe (SR)", "Super Creek (SSR)", "Sweep Tosho (SR)", "Agnes Tachyon (SR)", "Narita Taishin (SR)", "Marvelous Sunday (SR)"]


# game.manual_setup(support_cards=support_cards, deck_name="Oguri Cap")

# %%
game._check_energy()

# %%
game._infirmary(confi = 1)

# %% [markdown]
# ## Train

# %%
game.train_horse_loop(turn=32)
# Out:
# 2025-08-07 02:40:10,010 - main - INFO - Turn 32: Race Main.
# 2025-08-07 02:40:10,096 - main - DEBUG - Turn 32: Status good today.
# 2025-08-07 02:40:10,097 - main - INFO - Turn 32: Following main agenda to race
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 game.train_horse_loop(turn=32)
#
# File g:\Umamusume\control_laptop.py:220, in UmaGame.train_horse_loop(self, name, supportcard, style, turn)
#     218     else:
#     219         self._check_multiq()
# --> 220         self.train_horse()
#     221 except ContinueException:
#     222     self.turn += 1
#
# File g:\Umamusume\control_laptop.py:282, in UmaGame.train_horse(self)
#     280     pass
#     281 elif self.turn in self.event_manage["manual_race_day"]:
# --> 282     self._manual_race()
#     283     self._after_a_race()
#     285 self._check_energy()
#
# File g:\Umamusume\control_laptop.py:332, in UmaGame._manual_race(self)
#     330 logger.info(f"Turn {self.turn}: Following main agenda to race")
#     331 self.click(self.cfg["root"]["daily_training"]["race_day"], self.cfg["wait_time"]["_check_mainrace"]["register"])
# --> 332 self.find_race()
#     333 self.click(self.cfg["lobby_ui"]["race_enter"], self.cfg["wait_time"]["_check_mainrace"]["register"])
#     334 self.click(self.cfg["lobby_ui"]["race_confirm_button"], self.cfg["wait_time"]["_check_mainrace"]["event_wait"])
#
# File g:\Umamusume\control_laptop.py:344, in UmaGame.find_race(self)
#     343 def find_race(self):
# --> 344     race_name = self.character.race_table[self.turn]
#     345     print(f"Find {race_name}")
#     346     while True:
#
# KeyError: 32

# %%
support_cards = ["Mayano Top Gun (SR)", "Manhattan Cafe (SR)", "Sakura Bakushin O (SSR)", "Special Week (SSR)", "Sweep Tosho (SR)", "Kitasan Black (SSR)"]


game._manual_setup(support_cards=support_cards, deck_name="El Condor")

# %%
game.race_day = [100]
game.turn = 30

# %%
game.new_year_event()

# %%
import pyautogui
def get_mouse_position():
    """Get the current mouse position.
    FOR TEST/LABEL ONLY
    """
    return pyautogui.position()
x, y = get_mouse_position()
print([x-game.x, y-game.y])
# Out:
# [549, 615]

# %%
import pyautogui
top_x, top_y = 552, 453
bottom_x, bottom_y = 549, 603

# %%
pyautogui.moveTo(bottom_x+game.x, bottom_y+game.y)
pyautogui.dragTo(top_x+game.x, game.y+top_y,1)

# %%
import pyautogui
def get_mouse_position():
    """Get the current mouse position.
    FOR TEST/LABEL ONLY
    """
    return pyautogui.position()
x, y = get_mouse_position()
print([x, y])

# %%
x, y = get_mouse_position()
print([x-game.x, y-game.y])

# %%
693-641

# %% [markdown]
# # Capture

# %%
import time, pyautogui
capture_img = pyautogui.screenshot(region=(game.x, game.y, game.w, game.h))

# %%
capture_img.save(f"capture.png")

# %%
from utils.detect_text import ScreenTextReader
screen_text_reader = ScreenTextReader()

# %%
top, left = 416, 176
bottom, right = 461, 212

# %%
screen_text_reader.detect_text_in_image("capture.png", region=(top, left, bottom, right))

# %%
support_cards = ["Silence Suzuka (SSR)", "Kitasan Black (SSR)", "Daitaku Helios (SR)", "Air Groove (SR)", "Fuji Kiseki (SR)", "Yaeno Muteki (SSR)"]


game._manual_setup(support_cards=support_cards, deck_name="Mayano Top Gun Wedding")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 support_cards = ["Silence Suzuka (SSR)", "Kitasan Black (SSR)", "Daitaku Helios (SR)", "Air Groove (SR)", "Fuji Kiseki (SR)", "Yaeno Muteki (SSR)"]
# ----> 4 game._manual_setup(support_cards=support_cards, deck_name="Mayano Top Gun Wedding")
#
# NameError: name 'game' is not defined

# %%
from control_laptop import test_image
test_image(f"tscard/Sweep Tosho (SR)", returncoordinate=True)

# %%
from control_laptop import click_true
click_true(2376, 502)

# %%
import pyautogui
pyautogui.locateOnScreen(f"figures_lap/tscard/Super Creek (SSR).png", confidence=0.90)

# %%
x

# %%
int(x[0]), int(x[1])

# %%
from control_laptop import test_image
test_image("URA/races/Hanshin Juvenile", confi=0.9)

# %%
pyautogui.dragTo(1578, 630, duration=1)  # drag mouse to XY

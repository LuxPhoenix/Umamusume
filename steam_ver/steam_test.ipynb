# %% [markdown]
# # Run steam version
#
# - After you see training UI that have "Rest", "Training", "Skill",... run the code below, the screen size will automatic will change to 1440x

# %%
from control_laptop import UmaGame
import pygetwindow as gw
from horse_info import *

game = UmaGame(test=1, deck_name="Oguri Cap", character=Oguri_Cap)
# Out:
# Initialize logger for main
# Continue to next turn.

# %%
game.x, game.y

# %% [markdown]
# ## Test function

# %%
#TEST: Check change strategy at turn 22
game.turn=12
game.change_strategy()

# %%
#
game.turn=46
game.find_race()
# game._manual_race()
# Out:
# Find Queen Elizabeth II Cup

# %%
game.character.race_table[24]

# %%
# support_cards = ["Manhattan Cafe (SR)", "Super Creek (SSR)", "Sweep Tosho (SR)", "Agnes Tachyon (SR)", "Narita Taishin (SR)", "Marvelous Sunday (SR)"]


# game.manual_setup(support_cards=support_cards, deck_name="Oguri Cap")

# %%
game._check_energy()

# %%
game._infirmary(confi = 0.995)
# Out:
# 2025-09-27 19:57:44,478 - main - DEBUG - Turn 35: Status good today.

# %%
#TEST: Check mood
game.turn = 5
game._check_mood()
# Out:
# 2025-09-27 19:48:07,252 - main - INFO - Turn 5: Raise mood by recreation.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 #TEST: Check mood
#       2 game.turn = 5
# ----> 3 game._check_mood()
#
# File c:\Users\Administrator\Umamusume\steam_ver\control_laptop.py:563, in UmaGame._check_mood(self)
#     561 if test_image(f"mood/{i}", confi=0.85):
#     562     self.__raise_mood__()
# --> 563     self.__date_event__()
#     564     raise ContinueException
#     565 else:
#
# File c:\Users\Administrator\Umamusume\steam_ver\control_laptop.py:545, in UmaGame.__date_event__(self)
#     541 event_name = self.screen_reader.detect_text_in_image("test/screenshot.png", (top, left, bottom, right))
#     543 a, b, event = self.check_choice_event()
# --> 545 if event_name in self.data_event:
#     546     choice = self.special_events[event_name]["selectable"]
#     547     if choice:
#
# AttributeError: 'UmaGame' object has no attribute 'data_event'

# %%
#TEST: Change strategy
game.turn = 46
game.change_strategy()

# %%
# Get skill name
import pyautogui
# race_name = "Pace Strategy"
x = pyautogui.locateOnScreen(f"figures_lap/skill/Blue.png", confidence=0.8, region=(game.x+194, game.y+333, 469, 355))
# game.screen_reader.capture_screen(region=(game.x+194, game.y+333, 469, 355))
name_position = (int(x.left) + 48, int(x.top) - 20, 226, 30)
game.screen_reader.capture_screen(region=name_position)

# %%
game.screen_reader.detectt_tex_in_image(region=name_position)

# %%
"""
upgrade_skill_want = Mambo
if upgrade_skill_want:
    from screen:
        finded = find blue skill
        if finded:
            name = get_name()
            if 'Corner Recovery' in grade_skill_want:    #FIXME: 'Corner Rec0very O'
                upgrade()
                upgrade_skill_want.remove('Corner Recovery')
    roll down:
        hahaha = check is image_end:
            if hahaha:
                break
        else:
            pyautogui.scroll(-500)
click back button
"""

# %%
import pyautogui, time
pyautogui.locateOnScreen(f"figures_lap/skill/Blue.png", confidence=0.97, region=(game.x+194, game.y+333, 469, 355))

# %%
pyautogui.click(1294, 560)

# %%
import pyautogui, time

upgrade_skill_want = ['Corner Recovery O']
while True:
    if upgrade_skill_want:
        # Search for blue skill on screen
        try:
            finded = pyautogui.locateOnScreen(f"figures_lap/skill/Blue.png", confidence=0.8, region=(game.x+194, game.y+333, 469, 355))
        except:
            finded = None
        if finded:
            # Get skill name position and capture text
            name_position = (int(finded.left) + 48, int(finded.top) - 20, 226, 30)
            game.screen_reader.capture_screen(region=name_position)
            skill_name = game.screen_reader.detect_text_in_image('test/screenshot.png')
            
            # Check if desired skill is found
            if 'Corner Recovery' in skill_name:  # Fixed variable name from grade_skill_want
                """
                pyautogui.getpixel(finded.left+10, finded.top-5)
                if not white, skip because not have enough point
                else: upgrade and confirm
                """
                # Click to upgrade the skill
                pyautogui.click(int(finded.left) + 48, int(finded.top) - 20)
                pyautogui.click(1460, 546)  # Upgrade button
                print(f"Find corner recovery o")
                upgrade_skill_want.remove('Corner Recovery O')
                if not upgrade_skill_want:
                    print("All skills upgraded")
                    break
    # break            
        # Scroll down to check for more skills
        try:
            end_check = pyautogui.locateOnScreen("figures_lap/skill_end.png", confidence=0.8)
            print("Find end check")
            break
        except:
            pyautogui.click(x = game.x+493, y = game.y+398)
            time.sleep(5)
            for _ in range(8):
                pyautogui.scroll(-1)
            print("Scroll down")
            
                
    # except Exception as e:
    #     print(f"Error during skill upgrade: {e}")
        
    # Click back button when done
    # pyautogui.click(back_button_x, back_button_y)  # Add actual coordinates

# %%
import pyautogui
pyautogui.moveTo(x = game.x+493, y = game.y+398)

# %%
try:
    end_check = pyautogui.locateOnScreen("figures_lap/skill_end.png", confidence=0.8)
    pyautogui.click(end_check)
except:
    scroll_down()
    check_skill()

# %%
skill_name = game.screen_reader.detect_text_in_image('test/screenshot.png')

# %%
'Corner Rec0very O'

# %%
pyautogui.locateOnScreen(f"figures_lap/skill/Blue.png", confidence=0.8, region=(game.x+194, game.y+333, 469, 355))

# %%
pyautogui.click(name_position)

# %%
pyautogui.click(1460, 546)

# %%
SKILL_TO_SKILL_NAME = (48, -20)

# %%
1460 - 1412 = 48
546 - 566 = -20

# %% [markdown]
# ## Train

# %%
game.train_horse_loop(turn=53)
# Out:
# 2025-09-27 20:38:11,935 - main - INFO - Turn 53: No choice event, training UI detected.
# 2025-09-27 20:38:12,103 - main - DEBUG - Turn 53: Status good today.
# 2025-09-27 20:38:12,104 - main - INFO - Turn 53: Following main agenda to race
# Find Osaka Hai
# ---------------------------------------------------------------------------
# ImageNotFoundException                    Traceback (most recent call last)
# File c:\ProgramData\miniconda3\envs\Umamusume\Lib\site-packages\pyautogui\__init__.py:172, in raisePyAutoGUIImageNotFoundException.<locals>.wrapper(*args, **kwargs)
#     171 try:
# --> 172     return wrappedFunction(*args, **kwargs)
#     173 except pyscreeze.ImageNotFoundException:
#
# File c:\ProgramData\miniconda3\envs\Umamusume\Lib\site-packages\pyautogui\__init__.py:210, in locateOnScreen(*args, **kwargs)
#     208 @raisePyAutoGUIImageNotFoundException
#     209 def locateOnScreen(*args, **kwargs):
# --> 210     return pyscreeze.locateOnScreen(*args, **kwargs)
#
# File c:\ProgramData\miniconda3\envs\Umamusume\Lib\site-packages\pyscreeze\__init__.py:405, in locateOnScreen(image, minSearchTime, **kwargs)
#     404 screenshotIm = screenshot(region=None)
# --> 405 retVal = locate(image, screenshotIm, **kwargs)
#     406 try:
#
# File c:\ProgramData\miniconda3\envs\Umamusume\Lib\site-packages\pyscreeze\__init__.py:383, in locate(needleImage, haystackImage, **kwargs)
#     382 kwargs['limit'] = 1
# --> 383 points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#     384 if len(points) > 0:
#
# File c:\ProgramData\miniconda3\envs\Umamusume\Lib\site-packages\pyscreeze\__init__.py:257, in _locateAll_opencv(needleImage, haystackImage, grayscale, limit, region, step, confidence)
#     256 if USE_IMAGE_NOT_FOUND_EXCEPTION:
# --> 257     raise ImageNotFoundException('Could not locate the image (highest confidence = %.3f)' % result.max())
#     258 else:
#
# ImageNotFoundException: Could not locate the image (highest confidence = 0.847)
#
# During handling of the above exception, another exception occurred:
#
# ImageNotFoundException                    Traceback (most recent call last)
# File c:\Users\Administrator\Umamusume\steam_ver\control_laptop.py:389, in UmaGame._after_a_race(self)
#     388 try:
# --> 389     _, _ = identify_image("generaltraining/TraineeEvent", confidence=0.99)
#     390     a, b = identify_image("generaltraining/hi_g")
#
# File c:\Users\Administrator\Umamusume\steam_ver\control_laptop.py:643, in identify_image(name, confidence)
#     638 """Identify the required png.
#     639
#     640 Return the true central coordinate of the image.
#     641 If no image is identified, it will raise
#     642 pyautogui.ImageNotFoundException."""
# --> 643 l, t, w, h = pyautogui.locateOnScreen(f"figures_lap/{name}.png", confidence=confidence)
#     644 # print(l, t, w, h)
#
# File c:\ProgramData\miniconda3\envs\Umamusume\Lib\site-packages\pyautogui\__init__.py:174, in raisePyAutoGUIImageNotFoundException.<locals>.wrapper(*args, **kwargs)
#     173 except pyscreeze.ImageNotFoundException:
# --> 174     raise ImageNotFoundException
#
# ImageNotFoundException:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 game.train_horse_loop(turn=53)
#
# File c:\Users\Administrator\Umamusume\steam_ver\control_laptop.py:220, in UmaGame.train_horse_loop(self, name, supportcard, style, turn)
#     218     else:
#     219         self._check_multiq()
# --> 220         self.train_horse()
#     221 except ContinueException:
#     222     self.turn += 1
#
# File c:\Users\Administrator\Umamusume\steam_ver\control_laptop.py:283, in UmaGame.train_horse(self)
#     281 elif self.turn in self.event_manage["manual_race_day"]:
#     282     self._manual_race()
# --> 283     self._after_a_race()
#     285 self._check_energy()
#     287 mood_score = 3 if self._check_mood() else 0
#
# File c:\Users\Administrator\Umamusume\steam_ver\control_laptop.py:395, in UmaGame._after_a_race(self)
#     393 except ImageNotFoundException:
#     394     try:
# --> 395         a, b = identify_image("generaltraining/SupportCardEvent", confidence=0.99)
#     396         click_true(a, b + 82 * 0, self.cfg["wait_time"]["_check_special_"])  # Click on the first option.
#     397         logger.info(f"Turn {self.turn}: Support card event detected.")
#
# File c:\Users\Administrator\Umamusume\steam_ver\control_laptop.py:643, in identify_image(name, confidence)
#     637 def identify_image(name="Sweep Tosho", confidence=0.9):
#     638     """Identify the required png.
#     639
#     640     Return the true central coordinate of the image.
#     641     If no image is identified, it will raise
#     642     pyautogui.ImageNotFoundException."""
# --> 643     l, t, w, h = pyautogui.locateOnScreen(f"figures_lap/{name}.png", confidence=confidence)
#     644     # print(l, t, w, h)
#     645     return (l+w/2, t+h/2)
#
# File c:\ProgramData\miniconda3\envs\Umamusume\Lib\site-packages\pyautogui\__init__.py:172, in raisePyAutoGUIImageNotFoundException.<locals>.wrapper(*args, **kwargs)
#     169 @functools.wraps(wrappedFunction)
#     170 def wrapper(*args, **kwargs):
#     171     try:
# --> 172         return wrappedFunction(*args, **kwargs)
#     173     except pyscreeze.ImageNotFoundException:
#     174         raise ImageNotFoundException
#
# File c:\ProgramData\miniconda3\envs\Umamusume\Lib\site-packages\pyautogui\__init__.py:210, in locateOnScreen(*args, **kwargs)
#     208 @raisePyAutoGUIImageNotFoundException
#     209 def locateOnScreen(*args, **kwargs):
# --> 210     return pyscreeze.locateOnScreen(*args, **kwargs)
#
# File c:\ProgramData\miniconda3\envs\Umamusume\Lib\site-packages\pyscreeze\__init__.py:405, in locateOnScreen(image, minSearchTime, **kwargs)
#     401 try:
#     402     # the locateAll() function must handle cropping to return accurate coordinates,
#     403     # so don't pass a region here.
#     404     screenshotIm = screenshot(region=None)
# --> 405     retVal = locate(image, screenshotIm, **kwargs)
#     406     try:
#     407         screenshotIm.fp.close()
#
# File c:\ProgramData\miniconda3\envs\Umamusume\Lib\site-packages\pyscreeze\__init__.py:383, in locate(needleImage, haystackImage, **kwargs)
#     380 # Note: The gymnastics in this function is because we want to make sure to exhaust the iterator so that
#     381 # the needle and haystack files are closed in locateAll.
#     382 kwargs['limit'] = 1
# --> 383 points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#     384 if len(points) > 0:
#     385     return points[0]
#
# File c:\ProgramData\miniconda3\envs\Umamusume\Lib\site-packages\pyscreeze\__init__.py:233, in _locateAll_opencv(needleImage, haystackImage, grayscale, limit, region, step, confidence)
#     231 needleImage = _load_cv2(needleImage, grayscale)
#     232 needleHeight, needleWidth = needleImage.shape[:2]
# --> 233 haystackImage = _load_cv2(haystackImage, grayscale)
#     235 if region:
#     236     haystackImage = haystackImage[region[1] : region[1] + region[3], region[0] : region[0] + region[2]]
#
# File c:\ProgramData\miniconda3\envs\Umamusume\Lib\site-packages\pyscreeze\__init__.py:206, in _load_cv2(img, grayscale)
#     203         img_cv = img
#     204 elif hasattr(img, 'convert'):
#     205     # assume its a PIL.Image, convert to cv format
# --> 206     img_array = numpy.array(img.convert('RGB'))
#     207     img_cv = img_array[:, :, ::-1].copy()  # -1 does RGB -> BGR
#     208     if grayscale:
#
# File c:\ProgramData\miniconda3\envs\Umamusume\Lib\site-packages\PIL\Image.py:998, in Image.convert(self, mode, matrix, dither, palette, colors)
#     996         mode = "RGBA"
#     997 if not mode or (mode == self.mode and not matrix):
# --> 998     return self.copy()
#    1000 if matrix:
#    1001     # matrix conversion
#    1002     if mode not in ("L", "RGB"):
#
# File c:\ProgramData\miniconda3\envs\Umamusume\Lib\site-packages\PIL\Image.py:1276, in Image.copy(self)
#    1268 """
#    1269 Copies this image. Use this method if you wish to paste things
#    1270 into an image, but still retain the original.
#    (...)   1273 :returns: An :py:class:`~PIL.Image.Image` object.
#    1274 """
#    1275 self.load()
# -> 1276 return self._new(self.im.copy())
#
# KeyboardInterrupt:

# %%
game.event_manage
# Out:
# {'Sakura Bakushin O (SSR)': {"Bakushin's Cooking!": 'Auto',
#   "Bakushin's Love!": 'Auto',
#   "Bakushin's Huge Success!": 'Auto',
#   'Genius Efficiency!': 0,
#   'Enough to Break into a Dash!': 0},
#  'Manhattan Cafe (SR)': {'Invitation on a Rainy Day': 'Auto',
#   'Invitation on a Stormy Day': 'Auto',
#   'Solo Nighttime Run': 0,
#   'A Taste of Silence': 0},
#  'Super Creek (SSR)': {'Freshly Made in Ample Amounts': 'Auto',
#   'The Taste of Warmth': 'Auto',
#   'Have a Second Helping!': 'Auto',
#   'Leave it to Me to Help Out! ♪': 0,
#   'Leave it to Me to Be Considerate! ♪': 0},
#  'Special Week (SSR)': {'Dance in Cleats!': 'Auto',
#   'A Roller Coaster of Feelings!': 0,
#   'Our Audience': 'Auto',
#   "Watch Where You're Going!": 0,
#   'So Many Options!': 0},
#  'Sweep Tosho (SR)': {'Some Very Green Friends': 0,
#   'Premeditated Mischief': 0,
#   'Miracle ☆ Escape!': 0,
#   'Wonderful ☆ Mistake!': 0},
#  'Kitasan Black (SSR)': {'Chasing Brilliance': 'Auto',
#   'Paying It Forward': 0,
#   'We Walk Together': 'Auto',
#   'Ah, Friendship': 0,
#   'Ah, Home Sweet Home': 0},
#  'race_table': {'23': 'Hanshin Juvenile',
#   '24': 'Hopeful S',
#   '32': 'Oka Sho',
#   '35': 'Japan Derby',
#   '45': 'Queen Elizabeth II Cup',
#   '51': 'February Stakes',
#   '53': 'Osaka Hai',
#   '58': 'Victoria Mile',
#   '61': 'Yasuda Kinen',
#   '72': 'Japan C'},
#  'manual_race_day': [22, 23, 30, 32, 33, 45, 53, 58, 59, 61, 72],
#  'race_day': [11, 33, 44, 47, 68, 72]}

# %%
game.race_day = [100]
game.turn = 30

# %%
game.new_year_event()

# %%
import pyautogui
def get_mouse_position():
    """Get the current mouse position.
    FOR TEST/LABEL ONLY
    """
    return pyautogui.position()
x, y = get_mouse_position()
print([x-game.x, y-game.y])

# %%
import pyautogui
top_x, top_y = 552, 453
bottom_x, bottom_y = 549, 603

# %%
pyautogui.moveTo(bottom_x+game.x, bottom_y+game.y)
pyautogui.dragTo(top_x+game.x, game.y+top_y,1)

# %%
import pyautogui
def get_mouse_position():
    """Get the current mouse position.
    FOR TEST/LABEL ONLY
    """
    return pyautogui.position()
x, y = get_mouse_position()
x, y

# %%
import pyautogui
def get_mouse_position():
    """Get the current mouse position.
    FOR TEST/LABEL ONLY
    """
    return pyautogui.position()
x, y = get_mouse_position()
print([x, y])

# %%
x, y = get_mouse_position()
print([x-game.x, y-game.y])

# %%
693-641

# %% [markdown]
# # Capture

# %%
import time, pyautogui
capture_img = pyautogui.screenshot(region=(game.x, game.y, game.w, game.h))

# %%
capture_img.save(f"capture.png")

# %%
from utils.detect_text import ScreenTextReader
screen_text_reader = ScreenTextReader()

# %%
top, left = 416, 176
bottom, right = 461, 212

# %%
screen_text_reader.detect_text_in_image("capture.png", region=(top, left, bottom, right))

# %%
support_cards = ["Silence Suzuka (SSR)", "Kitasan Black (SSR)", "Daitaku Helios (SR)", "Air Groove (SR)", "Fuji Kiseki (SR)", "Yaeno Muteki (SSR)"]


game._manual_setup(support_cards=support_cards, deck_name="Mayano Top Gun Wedding")

# %%
from control_laptop import test_image
test_image(f"tscard/Sweep Tosho (SR)", returncoordinate=True)

# %%
from control_laptop import click_true
click_true(2376, 502)

# %%
import pyautogui
pyautogui.locateOnScreen(f"figures_lap/tscard/Super Creek (SSR).png", confidence=0.90)

# %%
x

# %%
int(x[0]), int(x[1])

# %%
from control_laptop import test_image
test_image("URA/races/Hanshin Juvenile", confi=0.9)

# %%
pyautogui.dragTo(1578, 630, duration=1)  # drag mouse to XY

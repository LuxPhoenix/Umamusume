# %% [markdown]
# # Run steam version
#
# - After you see training UI that have "Rest", "Training", "Skill",... run the code below, the screen size will automatic will change to 1440x

# %%
from control_laptop import UmaGame
import pygetwindow as gw
from horse_info import *

game = UmaGame(test=1, deck_name="Mayano Top Gun Wedding", character=Mayano_Top_Gun_Wedding)

# %% [markdown]
# ## Test function

# %%
#TEST: Check change strategy at turn 22
game.turn=22
game.change_strategy()

# %%
#
game.turn=22
game.find_race()

# %%
game.character.race_table[24]

# %%
# support_cards = ["Manhattan Cafe (SR)", "Super Creek (SSR)", "Sweep Tosho (SR)", "Agnes Tachyon (SR)", "Narita Taishin (SR)", "Marvelous Sunday (SR)"]


# game.manual_setup(support_cards=support_cards, deck_name="Oguri Cap")

# %%
game._check_energy()

# %%
game._infirmary(confi = 1)

# %%
#TEST: Check mood
game.turn = 5
game._check_mood()
# Out:
# 2025-09-21 15:47:57,241 - main - INFO - Turn 5: Raise mood by recreation.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 #TEST: Check mood
#       2 game.turn = 5
# ----> 3 game._check_mood()
#
# File c:\Users\Administrator\Downloads\Umamusume\steam_ver\control_laptop.py:558, in UmaGame._check_mood(self)
#     556 for i in bad_mood:
#     557     if test_image(f"mood/{i}", confi=0.85):
# --> 558         self.__raise_mood__()
#     559         self.__date_event__()
#     560         raise ContinueException
#
# File c:\Users\Administrator\Downloads\Umamusume\steam_ver\control_laptop.py:524, in UmaGame.__raise_mood__(self)
#     522 else:  # for summer training.
#     523     self.click(1450, 580)
# --> 524 time.sleep(self.cfg["wait_time"]["_raise_mood_"])
#
# KeyboardInterrupt:

# %% [markdown]
# ## Train

# %%
game.train_horse_loop(turn=4)
# Out:
# 2025-09-21 15:44:10,172 - main - INFO - Turn 3: No choice event, training UI detected.
# 2025-09-21 15:44:10,268 - main - DEBUG - Turn 3: Status good today.
# 2025-09-21 15:44:10,360 - main - INFO - Turn 3: Energy bar low, rest.
# 2025-09-21 15:44:19,357 - main - INFO - Turn 4: Find choice event.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 game.train_horse_loop(turn=3)
#
# File c:\Users\Administrator\Downloads\Umamusume\steam_ver\control_laptop.py:219, in UmaGame.train_horse_loop(self, name, supportcard, style, turn)
#     217         self.train_horse()
#     218     else:
# --> 219         self._check_multiq()
#     220         self.train_horse()
#     221 except ContinueException:
#
# File c:\Users\Administrator\Downloads\Umamusume\steam_ver\control_laptop.py:428, in UmaGame._check_multiq(self)
#     426 elif event == "choice_event":
#     427     logger.info(f"Turn {self.turn}: Find choice event.")
# --> 428     self.__check_special__(a, b)
#     429 else:
#     430     logger.info(f"Turn {self.turn}: Race Main.")
#
# File c:\Users\Administrator\Downloads\Umamusume\steam_ver\control_laptop.py:438, in UmaGame.__check_special__(self, a, b)
#     433 def __check_special__(self, a: float, b: float):
#     434     """Handle clicking for special events.
#     435
#     436     You really should not call this function alone."""
# --> 438     self.screen_reader.capture_screen(region=(self.x, self.y, self.w, self.h))
#     440     # Text region
#     441     event_region = self.cfg["event_capture"]["event_text"]
#
# File c:\Users\Administrator\Downloads\Umamusume\steam_ver\utils\detect_text.py:23, in ScreenTextReader.capture_screen(self, region)
#      19 """
#      20 Capture a screenshot of the specified region
#      21 """
#      22 screenshot = pyautogui.screenshot(region=region)
# ---> 23 screenshot.save(self.screenshot_path)
#      24 return self.screenshot_path
#
# File c:\ProgramData\anaconda3\envs\AutoGame\Lib\site-packages\PIL\Image.py:2583, in Image.save(self, fp, format, **params)
#    2581         fp = builtins.open(filename, "r+b")
#    2582     else:
# -> 2583         fp = builtins.open(filename, "w+b")
#    2584 else:
#    2585     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test/screenshot.png'

# %%
support_cards = ["Mayano Top Gun (SR)", "Manhattan Cafe (SR)", "Sakura Bakushin O (SSR)", "Special Week (SSR)", "Sweep Tosho (SR)", "Kitasan Black (SSR)"]


game._manual_setup(support_cards=support_cards, deck_name="El Condor")

# %%
game.race_day = [100]
game.turn = 30

# %%
game.new_year_event()

# %%
import pyautogui
def get_mouse_position():
    """Get the current mouse position.
    FOR TEST/LABEL ONLY
    """
    return pyautogui.position()
x, y = get_mouse_position()
print([x-game.x, y-game.y])

# %%
import pyautogui
top_x, top_y = 552, 453
bottom_x, bottom_y = 549, 603

# %%
pyautogui.moveTo(bottom_x+game.x, bottom_y+game.y)
pyautogui.dragTo(top_x+game.x, game.y+top_y,1)

# %%
import pyautogui
def get_mouse_position():
    """Get the current mouse position.
    FOR TEST/LABEL ONLY
    """
    return pyautogui.position()
x, y = get_mouse_position()
print([x, y])

# %%
x, y = get_mouse_position()
print([x-game.x, y-game.y])

# %%
693-641

# %% [markdown]
# # Capture

# %%
import time, pyautogui
capture_img = pyautogui.screenshot(region=(game.x, game.y, game.w, game.h))

# %%
capture_img.save(f"capture.png")

# %%
from utils.detect_text import ScreenTextReader
screen_text_reader = ScreenTextReader()

# %%
top, left = 416, 176
bottom, right = 461, 212

# %%
screen_text_reader.detect_text_in_image("capture.png", region=(top, left, bottom, right))

# %%
support_cards = ["Silence Suzuka (SSR)", "Kitasan Black (SSR)", "Daitaku Helios (SR)", "Air Groove (SR)", "Fuji Kiseki (SR)", "Yaeno Muteki (SSR)"]


game._manual_setup(support_cards=support_cards, deck_name="Mayano Top Gun Wedding")

# %%
from control_laptop import test_image
test_image(f"tscard/Sweep Tosho (SR)", returncoordinate=True)

# %%
from control_laptop import click_true
click_true(2376, 502)

# %%
import pyautogui
pyautogui.locateOnScreen(f"figures_lap/tscard/Super Creek (SSR).png", confidence=0.90)

# %%
x

# %%
int(x[0]), int(x[1])

# %%
from control_laptop import test_image
test_image("URA/races/Hanshin Juvenile", confi=0.9)

# %%
pyautogui.dragTo(1578, 630, duration=1)  # drag mouse to XY

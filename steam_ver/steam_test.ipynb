# %% [markdown]
# # Run steam version
#
# - After you see training UI that have "Rest", "Training", "Skill",... run the code below, the screen size will automatic will change to 1440x

# %%
from control_laptop import UmaGame
import pygetwindow as gw
from horse_info import *

game = UmaGame(test=1, deck_name="Maruzensky 2", character=Maruzensky_2)
# Out:
# Initialize logger for main
# Continue to next turn.

# %%
game.x, game.y

# %% [markdown]
# ## Test function

# %%
#TEST: Check change strategy at turn 22
game.turn=12
game.change_strategy()

# %%
#
game.turn=46
game.find_race()
# game._manual_race()

# %%
game.character.race_table[24]

# %%
support_cards =  ["Nishino Flower (SR)", "Kitasan Black (SSR)", "Air Groove (SR)", "Matikanefukukitaru (SR)", "Fuji Kiseki (SR)", "Yaeno Muteki (SSR)"]


game._manual_setup(support_cards=support_cards, deck_name="Maruzensky 2")
# Out:
# Manual setup completed. Data saved to dictionary.json.

# %%
game._check_energy()
# Out:
# 2025-10-11 16:05:04,731 - main - INFO - Turn 0: Energy bar safe.

# %%
game._infirmary(confi = 0.995)

# %%
#TEST: Check mood
game.turn = 5
game._check_mood()

# %%
game._upgrade_skill()
# Out:
# Scroll down
# Scroll down
# Scroll down
# Scroll down
# Find end check
# Skill upgrade checked.

# %%
#TEST: Change strategy
game.turn = 46
game.change_strategy()

# %%
# Get skill name
import pyautogui
# race_name = "Pace Strategy"
x = pyautogui.locateOnScreen(f"figures_lap/skill/Blue.png", confidence=0.8, region=(game.x+194, game.y+333, 469, 355))
# game.screen_reader.capture_screen(region=(game.x+194, game.y+333, 469, 355))
name_position = (int(x.left) + 48, int(x.top) - 20, 226, 30)
game.screen_reader.capture_screen(region=name_position)

# %%
game.screen_reader.detectt_tex_in_image(region=name_position)

# %%
"""
upgrade_skill_want = Mambo
if upgrade_skill_want:
    from screen:
        finded = find blue skill
        if finded:
            name = get_name()
            if 'Corner Recovery' in grade_skill_want:    #FIXME: 'Corner Rec0very O'
                upgrade()
                upgrade_skill_want.remove('Corner Recovery')
    roll down:
        hahaha = check is image_end:
            if hahaha:
                break
        else:
            pyautogui.scroll(-500)
click back button
"""

# %%
import pyautogui, time
pyautogui.locateOnScreen(f"figures_lap/skill/Blue.png", confidence=0.97, region=(game.x+194, game.y+333, 469, 355))

# %%
pyautogui.click(1294, 560)

# %%
import pyautogui, time

upgrade_skill_want = ['Corner Recovery O']
while True:
    if upgrade_skill_want:
        # Search for blue skill on screen
        try:
            finded = pyautogui.locateOnScreen(f"figures_lap/skill/Blue.png", confidence=0.8, region=(game.x+194, game.y+333, 469, 355))
        except:
            finded = None
        if finded:
            # Get skill name position and capture text
            name_position = (int(finded.left) + 48, int(finded.top) - 20, 226, 30)
            game.screen_reader.capture_screen(region=name_position)
            skill_name = game.screen_reader.detect_text_in_image('test/screenshot.png')
            
            # Check if desired skill is found
            if 'Corner Recovery' in skill_name:  # Fixed variable name from grade_skill_want
                """
                pyautogui.getpixel(finded.left+10, finded.top-5)
                if not white, skip because not have enough point
                else: upgrade and confirm
                """
                # Click to upgrade the skill
                pyautogui.click(int(finded.left) + 48, int(finded.top) - 20)
                pyautogui.click(1460, 546)  # Upgrade button
                print(f"Find corner recovery o")
                upgrade_skill_want.remove('Corner Recovery O')
                if not upgrade_skill_want:
                    print("All skills upgraded")
                    break
    # break            
        # Scroll down to check for more skills
        try:
            end_check = pyautogui.locateOnScreen("figures_lap/skill_end.png", confidence=0.8)
            print("Find end check")
            break
        except:
            pyautogui.click(x = game.x+493, y = game.y+398)
            time.sleep(5)
            for _ in range(8):
                pyautogui.scroll(-1)
            print("Scroll down")
            
                
    # except Exception as e:
    #     print(f"Error during skill upgrade: {e}")
        
    # Click back button when done
    # pyautogui.click(back_button_x, back_button_y)  # Add actual coordinates

# %%
import pyautogui
pyautogui.moveTo(x = game.x+493, y = game.y+398)

# %%
try:
    end_check = pyautogui.locateOnScreen("figures_lap/skill_end.png", confidence=0.8)
    pyautogui.click(end_check)
except:
    scroll_down()
    check_skill()

# %%
skill_name = game.screen_reader.detect_text_in_image('test/screenshot.png')

# %%
'Corner Rec0very O'

# %%
pyautogui.locateOnScreen(f"figures_lap/skill/Blue.png", confidence=0.8, region=(game.x+194, game.y+333, 469, 355))

# %%
pyautogui.click(name_position)

# %%
pyautogui.click(1460, 546)

# %%
SKILL_TO_SKILL_NAME = (48, -20)

# %%
1460 - 1412 = 48
546 - 566 = -20

# %% [markdown]
# ## Train

# %%
game.train_horse_loop(turn=0)
# Out:
# 2025-10-11 16:05:33,199 - main - INFO - Turn 0: No choice event, training UI detected.
# 2025-10-11 16:05:33,293 - main - DEBUG - Turn 0: Status good today.
# 2025-10-11 16:05:33,383 - main - INFO - Turn 0: Energy bar safe.
# 2025-10-11 16:05:33,383 - main - INFO - Turn 0: First turn, no mood check.
# 2025-10-11 16:05:33,384 - main - DEBUG - Turn 0: Check training options.
# The score under 2th training option is 0.8
# Empty relationship bar (0) is identified for Support Card: Kitasan Black (SSR), current friendship: 0
# 2025-10-11 16:05:36,948 - main - INFO - Turn 0: Training power with support cards ['Kitasan Black (SSR)'], score: 1.
# The score under 3th training option is 1.5
# Empty relationship bar (0) is identified for Support Card: Air Groove (SR), current friendship: 0
# 2025-10-11 16:05:37,755 - main - INFO - Turn 0: Training guts with support cards ['Air Groove (SR)', 'Yaeno Muteki (SSR)'], score: 2.
# Empty relationship bar (0) is identified for Support Card: Yaeno Muteki (SSR), current friendship: 0
# The score under 4th training option is 2.0
# 2025-10-11 16:05:38,382 - main - INFO - Turn 0: Training wits with support cards ['Nishino Flower (SR)', 'Fuji Kiseki (SR)'], score: 2.
# Empty relationship bar (0) is identified for Support Card: Nishino Flower (SR), current friendship: 0
# Empty relationship bar (0) is identified for Support Card: Fuji Kiseki (SR), current friendship: 0
# The score under 5th training option is 2.6
# The score under 1th training option is 1.5
# 2025-10-11 16:05:43,313 - main - INFO - Turn 0: Training wits with score 2.6.
# 2025-10-11 16:05:48,515 - main - INFO - Turn 0: No extra training event detected, event name:
# 2025-10-11 16:05:50,689 - main - INFO - Turn 1: No choice event, training UI detected.
# 2025-10-11 16:05:50,774 - main - DEBUG - Turn 1: Status good today.
# 2025-10-11 16:05:50,866 - main - INFO - Turn 1: Energy bar safe.
# 2025-10-11 16:05:51,820 - main - INFO - Turn 1: Raise mood by recreation.
# 2025-10-11 16:06:07,180 - main - INFO - Turn 1: No date event, training UI detected.
# 2025-10-11 16:06:09,352 - main - INFO - Turn 2: No choice event, training UI detected.
# 2025-10-11 16:06:09,445 - main - DEBUG - Turn 2: Status good today.
# 2025-10-11 16:06:09,529 - main - INFO - Turn 2: Energy bar safe.
# 2025-10-11 16:06:10,568 - main - INFO - Turn 2: Raise mood by recreation.
# 2025-10-11 16:06:25,857 - main - INFO - Turn 2: Find date event.
# 2025-10-11 16:06:25,946 - main - INFO - Turn 2: Find choice event.
# 2025-10-11 16:06:26,138 - main - INFO - Turn 2: Event name detected:
# 2025-10-11 16:06:26,954 - main - INFO - Turn 2: Can not found event in dictionary, choose default
# 2025-10-11 16:06:35,056 - main - INFO - Turn 2: Special event False not found in special events, choose green option.
# 2025-10-11 16:06:37,221 - main - INFO - Turn 3: No choice event, training UI detected.
# 2025-10-11 16:06:37,318 - main - DEBUG - Turn 3: Status good today.
# 2025-10-11 16:06:37,408 - main - INFO - Turn 3: Energy bar safe.
# 2025-10-11 16:06:37,834 - main - INFO - Turn 3: Mood is GREAT, no need to raise mood.
# 2025-10-11 16:06:37,835 - main - DEBUG - Turn 3: Check training options.
# Empty relationship bar (0) is identified for Support Card: Kitasan Black (SSR), current friendship: 0
# 2025-10-11 16:06:40,694 - main - INFO - Turn 3: Training speed with support cards ['Kitasan Black (SSR)', 'Fuji Kiseki (SR)', 'Yaeno Muteki (SSR)'], score: 3.
# Empty relationship bar (0) is identified for Support Card: Fuji Kiseki (SR), current friendship: 0
# Empty relationship bar (0) is identified for Support Card: Yaeno Muteki (SSR), current friendship: 0
# The score under 1th training option is 4.5
# The score under 2th training option is 0.8
# The score under 3th training option is 0.5
# The score under 4th training option is 0.0
# The score under 5th training option is 0.6
# 2025-10-11 16:06:47,417 - main - INFO - Turn 3: Training speed with score 4.5.
# 2025-10-11 16:06:52,620 - main - INFO - Turn 3: No extra training event detected, event name: Nostalgia Fever *
# 2025-10-11 16:06:54,702 - main - INFO - Turn 4: Find choice event.
# 2025-10-11 16:06:54,898 - main - INFO - Turn 4: Event name detected: Nostalgia Fever *
# 2025-10-11 16:06:55,519 - main - INFO - Turn 4: Can not found event in dictionary, choose default
# 2025-10-11 16:07:03,621 - main - INFO - Turn 4: Special event False not found in special events, choose green option.
# 2025-10-11 16:07:03,706 - main - DEBUG - Turn 4: Status good today.
# 2025-10-11 16:07:03,802 - main - INFO - Turn 4: Energy bar safe.
# 2025-10-11 16:07:04,272 - main - INFO - Turn 4: Mood is GREAT, no need to raise mood.
# 2025-10-11 16:07:04,273 - main - DEBUG - Turn 4: Check training options.
# The score under 2th training option is 0.8
# Empty relationship bar (0) is identified for Support Card: Kitasan Black (SSR), current friendship: 0
# 2025-10-11 16:07:07,944 - main - INFO - Turn 4: Training power with support cards ['Kitasan Black (SSR)'], score: 1.
# The score under 3th training option is 1.5
# Empty relationship bar (0) is identified for Support Card: Air Groove (SR), current friendship: 0
# 2025-10-11 16:07:08,714 - main - INFO - Turn 4: Training guts with support cards ['Air Groove (SR)'], score: 1.
# The score under 4th training option is 1.0
# Empty relationship bar (0) is identified for Support Card: Nishino Flower (SR), current friendship: 0
# 2025-10-11 16:07:09,457 - main - INFO - Turn 4: Training wits with support cards ['Nishino Flower (SR)', 'Fuji Kiseki (SR)'], score: 2.
# Empty relationship bar (0) is identified for Support Card: Fuji Kiseki (SR), current friendship: 0
# The score under 5th training option is 2.6
# 2025-10-11 16:07:09,977 - main - INFO - Turn 4: Training speed with support cards ['Yaeno Muteki (SSR)'], score: 1.
# Empty relationship bar (0) is identified for Support Card: Yaeno Muteki (SSR), current friendship: 0
# The score under 1th training option is 2.5
# 2025-10-11 16:07:14,560 - main - INFO - Turn 4: Training wits with score 2.6.
# 2025-10-11 16:07:19,749 - main - INFO - Turn 4: No extra training event detected, event name:
# 2025-10-11 16:07:21,926 - main - INFO - Turn 5: No choice event, training UI detected.
# 2025-10-11 16:07:22,013 - main - DEBUG - Turn 5: Status good today.
# 2025-10-11 16:07:22,108 - main - INFO - Turn 5: Energy bar safe.
# 2025-10-11 16:07:22,591 - main - INFO - Turn 5: Mood is GREAT, no need to raise mood.
# 2025-10-11 16:07:22,592 - main - DEBUG - Turn 5: Check training options.
# Empty relationship bar (0) is identified for Support Card: Nishino Flower (SR), current friendship: 0
# 2025-10-11 16:07:25,348 - main - INFO - Turn 5: Training speed with support cards ['Nishino Flower (SR)'], score: 1.
# The score under 1th training option is 2.5
# Empty relationship bar (0) is identified for Support Card: Kitasan Black (SSR), current friendship: 0
# 2025-10-11 16:07:26,096 - main - INFO - Turn 5: Training stamina with support cards ['Kitasan Black (SSR)'], score: 1.
# The score under 2th training option is 1.8
# 2025-10-11 16:07:26,759 - main - INFO - Turn 5: Training power with support cards ['Yaeno Muteki (SSR)'], score: 1.
# Empty relationship bar (0) is identified for Support Card: Yaeno Muteki (SSR), current friendship: 0
# The score under 3th training option is 1.5
# 2025-10-11 16:07:27,344 - main - INFO - Turn 5: Training guts with support cards ['Air Groove (SR)'], score: 1.
# Empty relationship bar (0) is identified for Support Card: Air Groove (SR), current friendship: 0
# The score under 4th training option is 1.0
# 2025-10-11 16:07:27,830 - main - INFO - Turn 5: Training wits with support cards ['Fuji Kiseki (SR)'], score: 1.
# Empty relationship bar (0) is identified for Support Card: Fuji Kiseki (SR), current friendship: 0
# The score under 5th training option is 1.9000000000000001
# 2025-10-11 16:07:32,413 - main - INFO - Turn 5: Training speed with score 2.5.
# 2025-10-11 16:07:37,611 - main - INFO - Turn 5: No extra training event detected, event name: Out of This World
# 2025-10-11 16:07:39,815 - main - INFO - Turn 6: No choice event, training UI detected.
# 2025-10-11 16:07:39,910 - main - DEBUG - Turn 6: Status good today.
# 2025-10-11 16:07:40,000 - main - INFO - Turn 6: Energy bar safe.
# 2025-10-11 16:07:40,434 - main - INFO - Turn 6: Mood is GREAT, no need to raise mood.
# 2025-10-11 16:07:40,435 - main - DEBUG - Turn 6: Check training options.
# The score under 2th training option is 0.8
# The score under 3th training option is 0.5
# The score under 4th training option is 0.0
# The score under 5th training option is 0.6
# The score under 1th training option is 1.5
# 2025-10-11 16:07:51,020 - main - INFO - Turn 6: Training speed with score 1.5.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 game.train_horse_loop(turn=0)
#
# File c:\Users\Administrator\Downloads\Umamusume\steam_ver\control_laptop.py:220, in UmaGame.train_horse_loop(self, name, supportcard, style, turn)
#     218     else:
#     219         self._check_multiq()
# --> 220         self.train_horse()
#     221 except ContinueException:
#     222     self.turn += 1
#
# File c:\Users\Administrator\Downloads\Umamusume\steam_ver\control_laptop.py:289, in UmaGame.train_horse(self)
#     285 self._check_energy()
#     287 mood_score = 3 if self._check_mood() else 0
# --> 289 self._check_training(mood_score)
#
# File c:\Users\Administrator\Downloads\Umamusume\steam_ver\control_laptop.py:680, in UmaGame._check_training(self, mood_score)
#     678         self.pre_trainoption = max_index
#     679         logger.info(f"Turn {self.turn}: Training {training_ls[max_index]} with score {score[max_index]}.")
# --> 680         self.__extra_training_event__()
#     681         raise ContinueException
#     682 except ImageNotFoundException as e:
#
# File c:\Users\Administrator\Downloads\Umamusume\steam_ver\control_laptop.py:637, in UmaGame.__extra_training_event__(self)
#     636 def __extra_training_event__(self):
# --> 637     time.sleep(5)
#     638     self.screen_reader.capture_screen(region=(self.x, self.y, self.w, self.h))
#     640     # Text region
#
# KeyboardInterrupt:

# %%
game.event_manage

# %%
game.race_day = [100]
game.turn = 30

# %%
game.new_year_event()

# %%
import pyautogui
def get_mouse_position():
    """Get the current mouse position.
    FOR TEST/LABEL ONLY
    """
    return pyautogui.position()
x, y = get_mouse_position()
print([x-game.x, y-game.y])

# %%
import pyautogui
top_x, top_y = 552, 453
bottom_x, bottom_y = 549, 603

# %%
pyautogui.moveTo(bottom_x+game.x, bottom_y+game.y)
pyautogui.dragTo(top_x+game.x, game.y+top_y,1)

# %%
import pyautogui
def get_mouse_position():
    """Get the current mouse position.
    FOR TEST/LABEL ONLY
    """
    return pyautogui.position()
x, y = get_mouse_position()
x, y

# %%
import pyautogui
def get_mouse_position():
    """Get the current mouse position.
    FOR TEST/LABEL ONLY
    """
    return pyautogui.position()
x, y = get_mouse_position()
print([x, y])

# %%
x, y = get_mouse_position()
print([x-game.x, y-game.y])

# %%
693-641

# %% [markdown]
# # Capture

# %%
import time, pyautogui
capture_img = pyautogui.screenshot(region=(game.x, game.y, game.w, game.h))

# %%
capture_img.save(f"capture.png")

# %%
from utils.detect_text import ScreenTextReader
screen_text_reader = ScreenTextReader()

# %%
top, left = 416, 176
bottom, right = 461, 212

# %%
screen_text_reader.detect_text_in_image("capture.png", region=(top, left, bottom, right))

# %%
support_cards = ["Silence Suzuka (SSR)", "Kitasan Black (SSR)", "Daitaku Helios (SR)", "Air Groove (SR)", "Fuji Kiseki (SR)", "Yaeno Muteki (SSR)"]


game._manual_setup(support_cards=support_cards, deck_name="Mayano Top Gun Wedding")

# %%
from control_laptop import test_image
test_image(f"tscard/Sweep Tosho (SR)", returncoordinate=True)

# %%
from control_laptop import click_true
click_true(2376, 502)

# %%
import pyautogui
pyautogui.locateOnScreen(f"figures_lap/tscard/Super Creek (SSR).png", confidence=0.90)

# %%
x

# %%
int(x[0]), int(x[1])

# %%
from control_laptop import test_image
test_image("URA/races/Hanshin Juvenile", confi=0.9)

# %%
pyautogui.dragTo(1578, 630, duration=1)  # drag mouse to XY

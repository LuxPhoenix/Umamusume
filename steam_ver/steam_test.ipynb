# %% [markdown]
# # Run steam version
#
# - After you see training UI that have "Rest", "Training", "Skill",... run the code below, the screen size will automatic will change to 1440x

# %%
from control_laptop import UmaGame
import pygetwindow as gw
from horse_info import *

game = UmaGame(test=1, deck_name="Mayano Top Gun Wedding", character=Mayano_Top_Gun_Wedding)
# Out:
# Initialize logger for main
# Continue to next turn.

# %%
game.x, game.y
# Out:
# (1066, 181)

# %% [markdown]
# ## Test function

# %%
#TEST: Check change strategy at turn 22
game.turn=23
game.change_strategy()

# %%
#
game.turn=23
game.find_race()
# game._manual_race()

# %%
game.character.race_table[24]

# %%
# support_cards = ["Manhattan Cafe (SR)", "Super Creek (SSR)", "Sweep Tosho (SR)", "Agnes Tachyon (SR)", "Narita Taishin (SR)", "Marvelous Sunday (SR)"]


# game.manual_setup(support_cards=support_cards, deck_name="Oguri Cap")

# %%
game._check_energy()

# %%
game._infirmary(confi = 1)

# %%
#TEST: Check mood
game.turn = 5
game._check_mood()

# %%
#TEST: Change strategy
game.turn = 23
game.change_strategy()

# %%
# Get skill name
import pyautogui
# race_name = "Pace Strategy"
x = pyautogui.locateOnScreen(f"figures_lap/skill/Blue.png", confidence=0.8, region=(game.x+194, game.y+333, 469, 355))
# game.screen_reader.capture_screen(region=(game.x+194, game.y+333, 469, 355))
name_position = (int(x.left) + 48, int(x.top) - 20, 226, 30)
game.screen_reader.capture_screen(region=name_position)
# Out:
# 'test/screenshot.png'

# %%
game.screen_reader.detectt_tex_in_image(region=name_position)

# %%
"""
upgrade_skill_want = Mambo
if upgrade_skill_want:
    from screen:
        finded = find blue skill
        if finded:
            name = get_name()
            if 'Corner Recovery' in grade_skill_want:    #FIXME: 'Corner Rec0very O'
                upgrade()
                upgrade_skill_want.remove('Corner Recovery')
    roll down:
        hahaha = check is image_end:
            if hahaha:
                break
        else:
            pyautogui.scroll(-500)
click back button
"""

# %%
import pyautogui, time
pyautogui.locateOnScreen(f"figures_lap/skill/Blue.png", confidence=0.97, region=(game.x+194, game.y+333, 469, 355))
# Out:
# Box(left=np.int64(1294), top=np.int64(750), width=62, height=53)

# %%
pyautogui.click(1294, 560)

# %%
import pyautogui, time

upgrade_skill_want = ['Corner Recovery O']
while True:
    if upgrade_skill_want:
        # Search for blue skill on screen
        try:
            finded = pyautogui.locateOnScreen(f"figures_lap/skill/Blue.png", confidence=0.8, region=(game.x+194, game.y+333, 469, 355))
        except:
            finded = None
        if finded:
            # Get skill name position and capture text
            name_position = (int(finded.left) + 48, int(finded.top) - 20, 226, 30)
            game.screen_reader.capture_screen(region=name_position)
            skill_name = game.screen_reader.detect_text_in_image('test/screenshot.png')
            
            # Check if desired skill is found
            if 'Corner Recovery' in skill_name:  # Fixed variable name from grade_skill_want
                """
                pyautogui.getpixel(finded.left+10, finded.top-5)
                if not white, skip because not have enough point
                else: upgrade and confirm
                """
                # Click to upgrade the skill
                pyautogui.click(int(finded.left) + 48, int(finded.top) - 20)
                pyautogui.click(1460, 546)  # Upgrade button
                print(f"Find corner recovery o")
                upgrade_skill_want.remove('Corner Recovery O')
                if not upgrade_skill_want:
                    print("All skills upgraded")
                    break
    # break            
        # Scroll down to check for more skills
        try:
            end_check = pyautogui.locateOnScreen("figures_lap/skill_end.png", confidence=0.8)
            print("Find end check")
            break
        except:
            pyautogui.click(x = game.x+493, y = game.y+398)
            time.sleep(5)
            for _ in range(8):
                pyautogui.scroll(-1)
            print("Scroll down")
            
                
    # except Exception as e:
    #     print(f"Error during skill upgrade: {e}")
        
    # Click back button when done
    # pyautogui.click(back_button_x, back_button_y)  # Add actual coordinates
# Out:
# Scroll down
# Find corner recovery o
# All skills upgraded

# %%
import pyautogui
pyautogui.moveTo(x = game.x+493, y = game.y+398)

# %%
try:
    end_check = pyautogui.locateOnScreen("figures_lap/skill_end.png", confidence=0.8)
    pyautogui.click(end_check)
except:
    scroll_down()
    check_skill()

# %%
skill_name = game.screen_reader.detect_text_in_image('test/screenshot.png')
# Out:
# 'Corner Recovery O'

# %%
'Corner Rec0very O'

# %%
pyautogui.locateOnScreen(f"figures_lap/skill/Blue.png", confidence=0.8, region=(game.x+194, game.y+333, 469, 355))
# Out:
# Box(left=np.int64(1293), top=np.int64(669), width=40, height=39)

# %%
pyautogui.click(name_position)

# %%
pyautogui.click(1460, 546)

# %%
SKILL_TO_SKILL_NAME = (48, -20)

# %%
1460 - 1412 = 48
546 - 566 = -20

# %% [markdown]
# ## Train

# %%
game.train_horse_loop(turn=26)
# Out:
# 2025-09-21 16:37:50,633 - main - INFO - Turn 26: No choice event, training UI detected.
# 2025-09-21 16:37:50,714 - main - DEBUG - Turn 26: Status good today.
# 2025-09-21 16:37:50,796 - main - INFO - Turn 26: Energy bar safe.
# 2025-09-21 16:37:51,148 - main - INFO - Turn 26: Mood is GREAT, no need to raise mood.
# 2025-09-21 16:37:51,149 - main - DEBUG - Turn 26: Check training options.
# The score under 2th training option is 0.6
# Empty relationship bar (0) is identified for Support Card: Silence Suzuka (SSR), current friendship: 0
# Empty relationship bar (0) is identified for Support Card: Daitaku Helios (SR), current friendship: 0
# 2025-09-21 16:37:54,823 - main - INFO - Turn 26: Training power with support cards ['Silence Suzuka (SSR)', 'Daitaku Helios (SR)', 'Fuji Kiseki (SR)', 'Yaeno Muteki (SSR)'], score: 4.
# Empty relationship bar (0) is identified for Support Card: Fuji Kiseki (SR), current friendship: 0
# Empty relationship bar (0) is identified for Support Card: Yaeno Muteki (SSR), current friendship: 0
# The score under 3th training option is 4.5
# The score under 4th training option is -0.5
# 2025-09-21 16:37:55,809 - main - INFO - Turn 26: Training wits with support cards ['Kitasan Black (SSR)', 'Air Groove (SR)'], score: 2.
# Empty relationship bar (0) is identified for Support Card: Kitasan Black (SSR), current friendship: 0
# Empty relationship bar (0) is identified for Support Card: Air Groove (SR), current friendship: 0
# The score under 5th training option is 2.1
# The score under 1th training option is 1.5
# 2025-09-21 16:38:00,657 - main - INFO - Turn 26: Training power with score 4.5.
# 2025-09-21 16:38:05,863 - main - INFO - Turn 26: No extra training event detected, event name: La
#
# Take Aim
# 2025-09-21 16:38:08,027 - main - INFO - Turn 27: No choice event, training UI detected.
# 2025-09-21 16:38:08,110 - main - DEBUG - Turn 27: Status good today.
# 2025-09-21 16:38:08,194 - main - INFO - Turn 27: Energy bar safe.
# 2025-09-21 16:38:08,555 - main - INFO - Turn 27: Mood is GREAT, no need to raise mood.
# 2025-09-21 16:38:08,556 - main - DEBUG - Turn 27: Check training options.
# 2025-09-21 16:38:11,341 - main - INFO - Turn 27: Training guts with support cards ['Fuji Kiseki (SR)'], score: 1.
# Empty relationship bar (0) is identified for Support Card: Fuji Kiseki (SR), current friendship: 0
# The score under 4th training option is 0.5
# Empty relationship bar (0) is identified for Support Card: Silence Suzuka (SSR), current friendship: 0
# 2025-09-21 16:38:12,149 - main - INFO - Turn 27: Training wits with support cards ['Silence Suzuka (SSR)'], score: 1.
# The score under 5th training option is 1.1
# The score under 1th training option is 1.5
# The score under 2th training option is 0.6
# Empty relationship bar (0) is identified for Support Card: Kitasan Black (SSR), current friendship: 0
# Empty relationship bar (0) is identified for Support Card: Daitaku Helios (SR), current friendship: 0
# 2025-09-21 16:38:14,333 - main - INFO - Turn 27: Training power with support cards ['Kitasan Black (SSR)', 'Daitaku Helios (SR)', 'Yaeno Muteki (SSR)'], score: 3.
# Empty relationship bar (0) is identified for Support Card: Yaeno Muteki (SSR), current friendship: 0
# The score under 3th training option is 3.5
# 2025-09-21 16:38:18,933 - main - INFO - Turn 27: Training power with score 3.5.
# 2025-09-21 16:38:24,123 - main - INFO - Turn 27: No extra training event detected, event name:
# 2025-09-21 16:38:26,292 - main - INFO - Turn 28: No choice event, training UI detected.
# 2025-09-21 16:38:26,385 - main - DEBUG - Turn 28: Status good today.
# 2025-09-21 16:38:26,466 - main - INFO - Turn 28: Energy bar safe.
# 2025-09-21 16:38:26,820 - main - INFO - Turn 28: Mood is GREAT, no need to raise mood.
# 2025-09-21 16:38:26,820 - main - DEBUG - Turn 28: Check training options.
# Empty relationship bar (0) is identified for Support Card: Air Groove (SR), current friendship: 0
# 2025-09-21 16:38:29,674 - main - INFO - Turn 28: Training guts with support cards ['Air Groove (SR)', 'Yaeno Muteki (SSR)'], score: 2.
# Empty relationship bar (0) is identified for Support Card: Yaeno Muteki (SSR), current friendship: 0
# The score under 4th training option is 1.5
# The score under 5th training option is 0.1
# 2025-09-21 16:38:30,994 - main - INFO - Turn 28: Training speed with support cards ['Fuji Kiseki (SR)'], score: 1.
# Empty relationship bar (0) is identified for Support Card: Fuji Kiseki (SR), current friendship: 0
# The score under 1th training option is 2.5
# 2025-09-21 16:38:31,560 - main - INFO - Turn 28: Training stamina with support cards ['Silence Suzuka (SSR)'], score: 1.
# Empty relationship bar (0) is identified for Support Card: Silence Suzuka (SSR), current friendship: 0
# The score under 2th training option is 1.6
# 2025-09-21 16:38:32,110 - main - INFO - Turn 28: Training power with support cards ['Kitasan Black (SSR)', 'Daitaku Helios (SR)'], score: 2.
# Empty relationship bar (0) is identified for Support Card: Kitasan Black (SSR), current friendship: 0
# Empty relationship bar (0) is identified for Support Card: Daitaku Helios (SR), current friendship: 0
# The score under 3th training option is 2.5
# 2025-09-21 16:38:36,713 - main - INFO - Turn 28: Training speed with score 2.5.
# 2025-09-21 16:38:41,908 - main - INFO - Turn 28: No extra training event detected, event name:
# ---------------------------------------------------------------------------
# ImageNotFoundException                    Traceback (most recent call last)
# File c:\ProgramData\anaconda3\envs\AutoGame\Lib\site-packages\pyautogui\__init__.py:172, in raisePyAutoGUIImageNotFoundException.<locals>.wrapper(*args, **kwargs)
#     171 try:
# --> 172     return wrappedFunction(*args, **kwargs)
#     173 except pyscreeze.ImageNotFoundException:
#
# File c:\ProgramData\anaconda3\envs\AutoGame\Lib\site-packages\pyautogui\__init__.py:210, in locateOnScreen(*args, **kwargs)
#     208 @raisePyAutoGUIImageNotFoundException
#     209 def locateOnScreen(*args, **kwargs):
# --> 210     return pyscreeze.locateOnScreen(*args, **kwargs)
#
# File c:\ProgramData\anaconda3\envs\AutoGame\Lib\site-packages\pyscreeze\__init__.py:405, in locateOnScreen(image, minSearchTime, **kwargs)
#     404 screenshotIm = screenshot(region=None)
# --> 405 retVal = locate(image, screenshotIm, **kwargs)
#     406 try:
#
# File c:\ProgramData\anaconda3\envs\AutoGame\Lib\site-packages\pyscreeze\__init__.py:383, in locate(needleImage, haystackImage, **kwargs)
#     382 kwargs['limit'] = 1
# --> 383 points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#     384 if len(points) > 0:
#
# File c:\ProgramData\anaconda3\envs\AutoGame\Lib\site-packages\pyscreeze\__init__.py:257, in _locateAll_opencv(needleImage, haystackImage, grayscale, limit, region, step, confidence)
#     256 if USE_IMAGE_NOT_FOUND_EXCEPTION:
# --> 257     raise ImageNotFoundException('Could not locate the image (highest confidence = %.3f)' % result.max())
#     258 else:
#
# ImageNotFoundException: Could not locate the image (highest confidence = 0.654)
#
# During handling of the above exception, another exception occurred:
#
# ImageNotFoundException                    Traceback (most recent call last)
# File c:\Users\Administrator\Downloads\Umamusume\steam_ver\control_laptop.py:147, in UmaGame.check_choice_event(self)
#     146 try:
# --> 147     a, b = identify_image("generaltraining/hi_g")
#     148     return a, b, "choice_event"
#
# File c:\Users\Administrator\Downloads\Umamusume\steam_ver\control_laptop.py:640, in identify_image(name, confidence)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\ProgramData\anaconda3\envs\AutoGame\Lib\site-packages\pyautogui\__init__.py:174, in raisePyAutoGUIImageNotFoundException.<locals>.wrapper(*args, **kwargs)
#     173 except pyscreeze.ImageNotFoundException:
# --> 174     raise ImageNotFoundException
#
# ImageNotFoundException:
#
# During handling of the above exception, another exception occurred:
#
# ImageNotFoundException                    Traceback (most recent call last)
# File c:\ProgramData\anaconda3\envs\AutoGame\Lib\site-packages\pyautogui\__init__.py:172, in raisePyAutoGUIImageNotFoundException.<locals>.wrapper(*args, **kwargs)
#     171 try:
# --> 172     return wrappedFunction(*args, **kwargs)
#     173 except pyscreeze.ImageNotFoundException:
#
# File c:\ProgramData\anaconda3\envs\AutoGame\Lib\site-packages\pyautogui\__init__.py:210, in locateOnScreen(*args, **kwargs)
#     208 @raisePyAutoGUIImageNotFoundException
#     209 def locateOnScreen(*args, **kwargs):
# --> 210     return pyscreeze.locateOnScreen(*args, **kwargs)
#
# File c:\ProgramData\anaconda3\envs\AutoGame\Lib\site-packages\pyscreeze\__init__.py:405, in locateOnScreen(image, minSearchTime, **kwargs)
#     404 screenshotIm = screenshot(region=None)
# --> 405 retVal = locate(image, screenshotIm, **kwargs)
#     406 try:
#
# File c:\ProgramData\anaconda3\envs\AutoGame\Lib\site-packages\pyscreeze\__init__.py:383, in locate(needleImage, haystackImage, **kwargs)
#     382 kwargs['limit'] = 1
# --> 383 points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#     384 if len(points) > 0:
#
# File c:\ProgramData\anaconda3\envs\AutoGame\Lib\site-packages\pyscreeze\__init__.py:257, in _locateAll_opencv(needleImage, haystackImage, grayscale, limit, region, step, confidence)
#     256 if USE_IMAGE_NOT_FOUND_EXCEPTION:
# --> 257     raise ImageNotFoundException('Could not locate the image (highest confidence = %.3f)' % result.max())
#     258 else:
#
# ImageNotFoundException: Could not locate the image (highest confidence = 0.575)
#
# During handling of the above exception, another exception occurred:
#
# ImageNotFoundException                    Traceback (most recent call last)
# File c:\Users\Administrator\Downloads\Umamusume\steam_ver\control_laptop.py:151, in UmaGame.check_choice_event(self)
#     150 try:
# --> 151     a, b = identify_image("generaltraining/training")
#     152     return None, None, "training"
#
# File c:\Users\Administrator\Downloads\Umamusume\steam_ver\control_laptop.py:640, in identify_image(name, confidence)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\ProgramData\anaconda3\envs\AutoGame\Lib\site-packages\pyautogui\__init__.py:174, in raisePyAutoGUIImageNotFoundException.<locals>.wrapper(*args, **kwargs)
#     173 except pyscreeze.ImageNotFoundException:
# --> 174     raise ImageNotFoundException
#
# ImageNotFoundException:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 game.train_horse_loop(turn=26)
#
# File c:\Users\Administrator\Downloads\Umamusume\steam_ver\control_laptop.py:219, in UmaGame.train_horse_loop(self, name, supportcard, style, turn)
#     217         self.train_horse()
#     218     else:
# --> 219         self._check_multiq()
#     220         self.train_horse()
#     221 except ContinueException:
#
# File c:\Users\Administrator\Downloads\Umamusume\steam_ver\control_laptop.py:425, in UmaGame._check_multiq(self)
#     423 def _check_multiq(self):
#     424     """Obtain support card special events (that do not choose green) and check for them then normal events."""
# --> 425     a, b, event = self.check_choice_event()
#     426     if event == "training":
#     427         logger.info(f"Turn {self.turn}: No choice event, training UI detected.")
#
# File c:\Users\Administrator\Downloads\Umamusume\steam_ver\control_laptop.py:155, in UmaGame.check_choice_event(self)
#     153 except ImageNotFoundException:
#     154     try:
# --> 155         a, b = identify_image("generaltraining/RaceMain")
#     156         return None, None, "race_main"
#     157     except ImageNotFoundException:
#     158         # try:
#     159         #     a, b = identify_image("generaltraining/RaceMain")
#     160         #     return None, None, "race_main"
#     161         # except ImageNotFoundException:
#
# File c:\Users\Administrator\Downloads\Umamusume\steam_ver\control_laptop.py:640, in identify_image(name, confidence)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\ProgramData\anaconda3\envs\AutoGame\Lib\site-packages\pyautogui\__init__.py:172, in raisePyAutoGUIImageNotFoundException.<locals>.wrapper(*args, **kwargs)
#     169 @functools.wraps(wrappedFunction)
#     170 def wrapper(*args, **kwargs):
#     171     try:
# --> 172         return wrappedFunction(*args, **kwargs)
#     173     except pyscreeze.ImageNotFoundException:
#     174         raise ImageNotFoundException
#
# File c:\ProgramData\anaconda3\envs\AutoGame\Lib\site-packages\pyautogui\__init__.py:210, in locateOnScreen(*args, **kwargs)
#     208 @raisePyAutoGUIImageNotFoundException
#     209 def locateOnScreen(*args, **kwargs):
# --> 210     return pyscreeze.locateOnScreen(*args, **kwargs)
#
# File c:\ProgramData\anaconda3\envs\AutoGame\Lib\site-packages\pyscreeze\__init__.py:404, in locateOnScreen(image, minSearchTime, **kwargs)
#     400 while True:
#     401     try:
#     402         # the locateAll() function must handle cropping to return accurate coordinates,
#     403         # so don't pass a region here.
# --> 404         screenshotIm = screenshot(region=None)
#     405         retVal = locate(image, screenshotIm, **kwargs)
#     406         try:
#
# File c:\ProgramData\anaconda3\envs\AutoGame\Lib\site-packages\pyscreeze\__init__.py:538, in _screenshot_win32(imageFilename, region, allScreens)
#     533 """
#     534 TODO
#     535 """
#     536 # TODO - Use the winapi to get a screenshot, and compare performance with ImageGrab.grab()
#     537 # https://stackoverflow.com/a/3586280/1893164
# --> 538 im = ImageGrab.grab(all_screens=allScreens)
#     539 if region is not None:
#     540     assert len(region) == 4, 'region argument must be a tuple of four ints'
#
# File c:\ProgramData\anaconda3\envs\AutoGame\Lib\site-packages\PIL\ImageGrab.py:66, in grab(bbox, include_layered_windows, all_screens, xdisplay, window)
#      60     all_screens = -1
#      61 offset, size, data = Image.core.grabscreen_win32(
#      62     include_layered_windows,
#      63     all_screens,
#      64     int(window) if window is not None else 0,
#      65 )
# ---> 66 im = Image.frombytes(
#      67     "RGB",
#      68     size,
#      69     data,
#      70     # RGB, 32-bit line padding, origin lower left corner
#      71     "raw",
#      72     "BGR",
#      73     (size[0] * 3 + 3) & -4,
#      74     -1,
#      75 )
#      76 if bbox:
#      77     x0, y0 = offset
#
# File c:\ProgramData\anaconda3\envs\AutoGame\Lib\site-packages\PIL\Image.py:3152, in frombytes(mode, size, data, decoder_name, *args)
#    3127 """
#    3128 Creates a copy of an image memory from pixel data in a buffer.
#    3129
#    (...)   3147 :returns: An :py:class:`~PIL.Image.Image` object.
#    3148 """
#    3150 _check_size(size)
# -> 3152 im = new(mode, size)
#    3153 if im.width != 0 and im.height != 0:
#    3154     decoder_args: Any = args
#
# File c:\ProgramData\anaconda3\envs\AutoGame\Lib\site-packages\PIL\Image.py:3117, in new(mode, size, color)
#    3115         im.palette = ImagePalette.ImagePalette()
#    3116         color = im.palette.getcolor(color_ints)
# -> 3117 return im._new(core.fill(mode, size, color))
#
# KeyboardInterrupt:

# %%
support_cards = ["Mayano Top Gun (SR)", "Manhattan Cafe (SR)", "Sakura Bakushin O (SSR)", "Special Week (SSR)", "Sweep Tosho (SR)", "Kitasan Black (SSR)"]


game._manual_setup(support_cards=support_cards, deck_name="El Condor")

# %%
game.race_day = [100]
game.turn = 30

# %%
game.new_year_event()

# %%
import pyautogui
def get_mouse_position():
    """Get the current mouse position.
    FOR TEST/LABEL ONLY
    """
    return pyautogui.position()
x, y = get_mouse_position()
print([x-game.x, y-game.y])
# Out:
# [510, 711]

# %%
import pyautogui
top_x, top_y = 552, 453
bottom_x, bottom_y = 549, 603

# %%
pyautogui.moveTo(bottom_x+game.x, bottom_y+game.y)
pyautogui.dragTo(top_x+game.x, game.y+top_y,1)

# %%
import pyautogui
def get_mouse_position():
    """Get the current mouse position.
    FOR TEST/LABEL ONLY
    """
    return pyautogui.position()
x, y = get_mouse_position()
x, y
# Out:
# (1460, 546)

# %%
import pyautogui
def get_mouse_position():
    """Get the current mouse position.
    FOR TEST/LABEL ONLY
    """
    return pyautogui.position()
x, y = get_mouse_position()
print([x, y])

# %%
x, y = get_mouse_position()
print([x-game.x, y-game.y])

# %%
693-641

# %% [markdown]
# # Capture

# %%
import time, pyautogui
capture_img = pyautogui.screenshot(region=(game.x, game.y, game.w, game.h))

# %%
capture_img.save(f"capture.png")

# %%
from utils.detect_text import ScreenTextReader
screen_text_reader = ScreenTextReader()

# %%
top, left = 416, 176
bottom, right = 461, 212

# %%
screen_text_reader.detect_text_in_image("capture.png", region=(top, left, bottom, right))

# %%
support_cards = ["Silence Suzuka (SSR)", "Kitasan Black (SSR)", "Daitaku Helios (SR)", "Air Groove (SR)", "Fuji Kiseki (SR)", "Yaeno Muteki (SSR)"]


game._manual_setup(support_cards=support_cards, deck_name="Mayano Top Gun Wedding")

# %%
from control_laptop import test_image
test_image(f"tscard/Sweep Tosho (SR)", returncoordinate=True)

# %%
from control_laptop import click_true
click_true(2376, 502)

# %%
import pyautogui
pyautogui.locateOnScreen(f"figures_lap/tscard/Super Creek (SSR).png", confidence=0.90)

# %%
x

# %%
int(x[0]), int(x[1])

# %%
from control_laptop import test_image
test_image("URA/races/Hanshin Juvenile", confi=0.9)

# %%
pyautogui.dragTo(1578, 630, duration=1)  # drag mouse to XY
